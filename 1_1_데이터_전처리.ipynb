# %% [markdown]
# # 중복/누락 데이터 처리

# %% [markdown]
# ## 1. 누락 데이터 제거

# %%
import pandas as pd
df=pd.read_csv('datacleaning.csv')

# %%
df
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60  117.0       145     479.0
# 1         60  103.0       135     340.0
# 2         45  109.0       175     282.4
# 3         45    NaN       148     406.0
# 4         60  100.0       120     250.7
# 5        450  104.0       134     253.3
# 6         30  109.0       133     195.1
# 7         60    NaN       124     269.0
# 8         60  103.0       147     329.3
# 9         60  100.0       120     250.7
# 10        60  100.0       120     250.7
# 11        60   98.0       120     215.2
# 12        45   90.0       112       NaN
# 13        60  103.0       123     323.0
# 14        60  100.0       120     250.7
# 15        45    NaN       132     246.0
# 16        60  102.0       126     334.5
# 17        60  100.0       120     250.0
# 18        60  103.0       132       NaN

# %% [markdown]
# ### 1-1. 누락 데이터 확인하기

# %%
# 열단위로 누락 데이터 확인하기
df.isnull().sum()
# Out:
# Duration    0
# Pulse       3
# Maxpulse    0
# Calories    2
# dtype: int64

# %% [markdown]
# ### 1-2. 결측치가 있는 행 날리기

# %%
df2=df.dropna(axis=0) # 행단위로 제거
df2
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60  117.0       145     479.0
# 1         60  103.0       135     340.0
# 2         45  109.0       175     282.4
# 4         60  100.0       120     250.7
# 5        450  104.0       134     253.3
# 6         30  109.0       133     195.1
# 8         60  103.0       147     329.3
# 9         60  100.0       120     250.7
# 10        60  100.0       120     250.7
# 11        60   98.0       120     215.2
# 13        60  103.0       123     323.0
# 14        60  100.0       120     250.7
# 16        60  102.0       126     334.5
# 17        60  100.0       120     250.0

# %% [markdown]
# ### 1-3. 결측치가 있는 열 날리기

# %%
df2=df.dropna(axis=1) #열단위로 제거
df2
# Out:
#     Duration  Maxpulse
# 0         60       145
# 1         60       135
# 2         45       175
# 3         45       148
# 4         60       120
# 5        450       134
# 6         30       133
# 7         60       124
# 8         60       147
# 9         60       120
# 10        60       120
# 11        60       120
# 12        45       112
# 13        60       123
# 14        60       120
# 15        45       132
# 16        60       126
# 17        60       120
# 18        60       132

# %% [markdown]
# ### 1-4. 결측치 메꾸기

# %%
df.fillna(130)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60  117.0       145     479.0
# 1         60  103.0       135     340.0
# 2         45  109.0       175     282.4
# 3         45  130.0       148     406.0
# 4         60  100.0       120     250.7
# 5        450  104.0       134     253.3
# 6         30  109.0       133     195.1
# 7         60  130.0       124     269.0
# 8         60  103.0       147     329.3
# 9         60  100.0       120     250.7
# 10        60  100.0       120     250.7
# 11        60   98.0       120     215.2
# 12        45   90.0       112     130.0
# 13        60  103.0       123     323.0
# 14        60  100.0       120     250.7
# 15        45  130.0       132     246.0
# 16        60  102.0       126     334.5
# 17        60  100.0       120     250.0
# 18        60  103.0       132     130.0

# %%
df['Calories'].fillna(130)
# Out:
# 0     479.0
# 1     340.0
# 2     282.4
# 3     406.0
# 4     250.7
# 5     253.3
# 6     195.1
# 7     269.0
# 8     329.3
# 9     250.7
# 10    250.7
# 11    215.2
# 12    130.0
# 13    323.0
# 14    250.7
# 15    246.0
# 16    334.5
# 17    250.0
# 18    130.0
# Name: Calories, dtype: float64

# %% [markdown]
# ### 1-5. 평균값으로 결측치 채우기

# %%
m =df['Calories'].mean()
m
# Out:
# 289.74117647058824

# %%
df['Calories'].fillna(m)
# Out:
# 0     479.000000
# 1     340.000000
# 2     282.400000
# 3     406.000000
# 4     250.700000
# 5     253.300000
# 6     195.100000
# 7     269.000000
# 8     329.300000
# 9     250.700000
# 10    250.700000
# 11    215.200000
# 12    289.741176
# 13    323.000000
# 14    250.700000
# 15    246.000000
# 16    334.500000
# 17    250.000000
# 18    289.741176
# Name: Calories, dtype: float64

# %% [markdown]
# ### 1-6. 중복값 제거

# %%
df.drop_duplicates()
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60  117.0       145     479.0
# 1         60  103.0       135     340.0
# 2         45  109.0       175     282.4
# 3         45    NaN       148     406.0
# 4         60  100.0       120     250.7
# 5        450  104.0       134     253.3
# 6         30  109.0       133     195.1
# 7         60    NaN       124     269.0
# 8         60  103.0       147     329.3
# 11        60   98.0       120     215.2
# 12        45   90.0       112       NaN
# 13        60  103.0       123     323.0
# 15        45    NaN       132     246.0
# 16        60  102.0       126     334.5
# 17        60  100.0       120     250.0
# 18        60  103.0       132       NaN

# %%
# keep 패러미터를 통해 중복값중 처음값을 살릴지 마지막값을 살릴지 선택 가능
df.drop_duplicates(keep='last')
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60  117.0       145     479.0
# 1         60  103.0       135     340.0
# 2         45  109.0       175     282.4
# 3         45    NaN       148     406.0
# 5        450  104.0       134     253.3
# 6         30  109.0       133     195.1
# 7         60    NaN       124     269.0
# 8         60  103.0       147     329.3
# 11        60   98.0       120     215.2
# 12        45   90.0       112       NaN
# 13        60  103.0       123     323.0
# 14        60  100.0       120     250.7
# 15        45    NaN       132     246.0
# 16        60  102.0       126     334.5
# 17        60  100.0       120     250.0
# 18        60  103.0       132       NaN

# %% [markdown]
# ### 1-7. 연쇄적 명령

# %%
# 여려 명령어를 다음과 같이 연쇄적으로 사용할 수 있음
df.dropna().drop_duplicates()
# df.dropna().drop_duplicates().describe()
# df.dropna().drop_duplicates().head()
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60  117.0       145     479.0
# 1         60  103.0       135     340.0
# 2         45  109.0       175     282.4
# 4         60  100.0       120     250.7
# 5        450  104.0       134     253.3
# 6         30  109.0       133     195.1
# 8         60  103.0       147     329.3
# 11        60   98.0       120     215.2
# 13        60  103.0       123     323.0
# 16        60  102.0       126     334.5
# 17        60  100.0       120     250.0

# %% [markdown]
# ## MinMax Scaling

# %%
df2=df.dropna(axis=0)

# %%
(df2.max()-df2)/(df2.max()-df2.min())
# Out:
#     Duration     Pulse  Maxpulse  Calories
# 0   0.928571  0.000000  0.545455  0.000000
# 1   0.928571  0.736842  0.727273  0.489609
# 2   0.964286  0.421053  0.000000  0.692497
# 4   0.928571  0.894737  1.000000  0.804156
# 5   0.000000  0.684211  0.745455  0.794998
# 6   1.000000  0.421053  0.763636  1.000000
# 8   0.928571  0.736842  0.509091  0.527298
# 9   0.928571  0.894737  1.000000  0.804156
# 10  0.928571  0.894737  1.000000  0.804156
# 11  0.928571  1.000000  1.000000  0.929200
# 13  0.928571  0.736842  0.945455  0.549489
# 14  0.928571  0.894737  1.000000  0.804156
# 16  0.928571  0.789474  0.890909  0.508982
# 17  0.928571  0.894737  1.000000  0.806622

# %% [markdown]
# ## Standard Scaling

# %%
(df2-df2.mean())/df2.std()
# Out:
#     Duration     Pulse  Maxpulse  Calories
# 0  -0.233557  2.663829  0.869933  2.699922
# 1  -0.233557 -0.084121  0.235607  0.754987
# 2  -0.375723  1.093572  2.772913 -0.050972
# 4  -0.233557 -0.672967 -0.715883 -0.494529
# 5   3.462742  0.112161  0.172174 -0.458149
# 6  -0.517888  1.093572  0.108742 -1.272503
# 8  -0.233557 -0.084121  0.996799  0.605269
# 9  -0.233557 -0.672967 -0.715883 -0.494529
# 10 -0.233557 -0.672967 -0.715883 -0.494529
# 11 -0.233557 -1.065532 -0.715883 -0.991257
# 13 -0.233557 -0.084121 -0.525585  0.517117
# 14 -0.233557 -0.672967 -0.715883 -0.494529
# 16 -0.233557 -0.280403 -0.335287  0.678029
# 17 -0.233557 -0.672967 -0.715883 -0.504324
