# %% [markdown]
# <a href="https://colab.research.google.com/github/ralbu85/DataScience_2022S/blob/master/01_1_%EA%B7%B8%EB%9E%98%ED%94%84%EA%B7%B8%EB%A6%AC%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('auto.csv')
df
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0  3504.0          12.0          70
# 1            8         350.0       165.0  3693.0          11.5          70
# 2            8         318.0       150.0  3436.0          11.0          70
# 3            8         304.0       150.0  3433.0          12.0          70
# 4            8         302.0       140.0  3449.0          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 387          4         140.0        86.0  2790.0          15.6          82
# 388          4          97.0        52.0  2130.0          24.6          82
# 389          4         135.0        84.0  2295.0          11.6          82
# 390          4         120.0        79.0  2625.0          18.6          82
# 391          4         119.0        82.0  2720.0          19.4          82
#
#      origin   mpg
# 0         1  18.0
# 1         1  15.0
# ...

# %% [markdown]
# ## 단일 변수의 분포 확인

# %%
# matplotlib 라이브러리 불러오기
import matplotlib.pyplot as plt

# %%
plt.hist(df['cylinders'])
# Out:
# (array([  4.,   0., 199.,   0.,   3.,   0.,  83.,   0.,   0., 103.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['horsepower'],15)
# Out:
# (array([15., 56., 51., 89., 46., 29., 15., 15., 36.,  8., 15.,  4.,  3.,
#          5.,  5.]),
#  array([ 46.        ,  58.26666667,  70.53333333,  82.8       ,
#          95.06666667, 107.33333333, 119.6       , 131.86666667,
#         144.13333333, 156.4       , 168.66666667, 180.93333333,
#         193.2       , 205.46666667, 217.73333333, 230.        ]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# ## 두 변수 사이의 관계: scatterplot

# %%
plt.scatter(df['horsepower'],df['mpg'])

# %%
plt.scatter(df['cylinders'], df['mpg'])

# %% [markdown]
# ## seaborn의 pairplot

# %%
import seaborn as sns

# %%
sns.pairplot(df)
