# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/ralbu85/DataScience_2022S/master/data/classification_data.csv')
df
# Out:
#           X1        X2  y
# 0  -2.056844 -0.752741  0
# 1   1.760238  1.558517  1
# 2  -0.447763 -1.554927  1
# 3   1.008459  0.529517  1
# 4   0.636547  0.409058  1
# ..       ...       ... ..
# 95 -0.129932 -0.797169  0
# 96  1.426902  1.244639  1
# 97 -0.582968  1.630750  1
# 98 -0.619720  1.630840  0
# 99  1.938929  0.069963  1
#
# [100 rows x 3 columns]

# %% [markdown]
# ## 학습하기

# %%
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression()
X = df[['X1','X2']]
y = df['y']
reg.fit(X,y)
# Out:
# LogisticRegression()

# %% [markdown]
# ## 예측결과 csv 파일로 만들고 다운받기

# %%
# !pip install google.colab
from google.colab import files
result=reg.predict(X) ## 학습된 모형을 예측하여 result 변수에 저장
pd.Series(result).to_csv('result.csv',index=False) ## result.csv 파일에 결과물 생성
files.download('result.csv') # 다운받기
# Out:
# Collecting google.colab
#   Downloading google-colab-1.0.0.tar.gz (72 kB)
#      |████████████████████████████████| 72 kB 1.0 MB/s
#   Preparing metadata (setup.py) ... done
# Collecting google-auth~=1.4.0
#   Downloading google_auth-1.4.2-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.4 MB/s
# Collecting ipykernel~=4.6.0
#   Downloading ipykernel-4.6.1-py3-none-any.whl (104 kB)
#      |████████████████████████████████| 104 kB 14.3 MB/s
# Collecting ipython~=5.5.0
#   Downloading ipython-5.5.0-py3-none-any.whl (758 kB)
#      |████████████████████████████████| 758 kB 13.2 MB/s
# Collecting notebook~=5.2.0
#   Downloading notebook-5.2.2-py2.py3-none-any.whl (8.0 MB)
#      |████████████████████████████████| 8.0 MB 12.6 MB/s
# Collecting six~=1.12.0
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting pandas~=0.24.0
#   Downloading pandas-0.24.2.tar.gz (11.8 MB)
#      |████████████████████████████████| 11.8 MB 10.7 MB/s
#   Preparing metadata (setup.py) ... done
# Collecting portpicker~=1.2.0
#   Downloading portpicker-1.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting requests~=2.21.0
#   Downloading requests-2.21.0-py2.py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 4.6 MB/s
# Collecting tornado~=4.5.0
#   Downloading tornado-4.5.3.tar.gz (484 kB)
#      |████████████████████████████████| 484 kB 12.7 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.8/site-packages (from google-auth~=1.4.0->google.colab) (0.2.8)
# Requirement already satisfied: cachetools>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from google-auth~=1.4.0->google.colab) (4.2.2)
# Requirement already satisfied: rsa>=3.1.4 in /opt/conda/lib/python3.8/site-packages (from google-auth~=1.4.0->google.colab) (4.8)
# Requirement already satisfied: jupyter-client in /opt/conda/lib/python3.8/site-packages (from ipykernel~=4.6.0->google.colab) (7.1.0)
# Requirement already satisfied: traitlets>=4.1.0 in /opt/conda/lib/python3.8/site-packages (from ipykernel~=4.6.0->google.colab) (5.2.2.post1)
# Collecting prompt-toolkit<2.0.0,>=1.0.4
#   Downloading prompt_toolkit-1.0.18-py3-none-any.whl (245 kB)
#      |████████████████████████████████| 245 kB 10.9 MB/s
# Requirement already satisfied: decorator in /opt/conda/lib/python3.8/site-packages (from ipython~=5.5.0->google.colab) (4.4.2)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.8/site-packages (from ipython~=5.5.0->google.colab) (2.11.1)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.8/site-packages (from ipython~=5.5.0->google.colab) (60.2.0)
# Requirement already satisfied: pexpect in /opt/conda/lib/python3.8/site-packages (from ipython~=5.5.0->google.colab) (4.8.0)
# Collecting simplegeneric>0.8
#   Downloading simplegeneric-0.8.1.zip (12 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.8/site-packages (from ipython~=5.5.0->google.colab) (0.7.5)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.8/site-packages (from notebook~=5.2.0->google.colab) (4.9.1)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.8/site-packages (from notebook~=5.2.0->google.colab) (6.5.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.8/site-packages (from notebook~=5.2.0->google.colab) (0.2.0)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.8/site-packages (from notebook~=5.2.0->google.colab) (5.1.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from notebook~=5.2.0->google.colab) (3.0.3)
# Requirement already satisfied: terminado>=0.3.3 in /opt/conda/lib/python3.8/site-packages (from notebook~=5.2.0->google.colab) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/conda/lib/python3.8/site-packages (from pandas~=0.24.0->google.colab) (2.8.2)
# Requirement already satisfied: pytz>=2011k in /opt/conda/lib/python3.8/site-packages (from pandas~=0.24.0->google.colab) (2021.3)
# Requirement already satisfied: numpy>=1.12.0 in /opt/conda/lib/python3.8/site-packages (from pandas~=0.24.0->google.colab) (1.19.5)
# Collecting idna<2.9,>=2.5
#   Downloading idna-2.8-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.4 MB/s
# Collecting urllib3<1.25,>=1.21.1
#   Downloading urllib3-1.24.3-py2.py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 10.9 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests~=2.21.0->google.colab) (2021.10.8)
# Collecting chardet<3.1.0,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 11.2 MB/s
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.8/site-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython~=5.5.0->google.colab) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth~=1.4.0->google.colab) (0.4.8)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.8/site-packages (from terminado>=0.3.3->notebook~=5.2.0->google.colab) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.8/site-packages (from jinja2->notebook~=5.2.0->google.colab) (2.0.1)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.8/site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (0.3)
# Requirement already satisfied: nest-asyncio>=1.5 in /opt/conda/lib/python3.8/site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (1.5.4)
# Requirement already satisfied: pyzmq>=13 in /opt/conda/lib/python3.8/site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (22.3.0)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.8/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (1.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.8/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.6.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.8/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (21.3)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.8/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (4.10.0)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.8/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.8/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.8/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (1.5.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.8/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.8/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.8.4)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.8/site-packages (from nbformat->notebook~=5.2.0->google.colab) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google.colab) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google.colab) (0.18.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google.colab) (5.4.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.8/site-packages (from beautifulsoup4->nbconvert->notebook~=5.2.0->google.colab) (2.3.1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.8/site-packages (from bleach->nbconvert->notebook~=5.2.0->google.colab) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging->nbconvert->notebook~=5.2.0->google.colab) (3.0.6)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google.colab) (3.7.0)
# Building wheels for collected packages: google.colab, pandas, portpicker, tornado, simplegeneric
#   Building wheel for google.colab (setup.py) ... done
#   Created wheel for google.colab: filename=google_colab-1.0.0-py2.py3-none-any.whl size=102292 sha256=2cc36aa45a3b62c5523e7d4d75d7ee84076c525cd5cb1e6336642911cdc4c274
#   Stored in directory: /root/.cache/pip/wheels/e4/e7/91/b2736701bca00e273fdc79f80e2727b558e0903d81b758eb69
#   Building wheel for pandas (setup.py) ... |
